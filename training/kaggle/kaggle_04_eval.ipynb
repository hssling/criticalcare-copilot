# %% [markdown]
# # 04 — Evaluate

# %%
# !python training/scripts/evaluate_checkpoint.py --adapter checkpoints/gemma4_e4b_qlora --suite smoke --out eval/reports/latest.json

# %%
import json, pathlib
print(json.dumps(json.loads(pathlib.Path('eval/reports/latest.json').read_text()), indent=2))
