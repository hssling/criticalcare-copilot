# %% [markdown]
# # 04 - Evaluation & Inference Checks
#
# This notebook runs standard inference evaluations using our benchmark harness to guarantee no regressions in abstraction or safety against our test sets.

# %%
# !pip -q install huggingface_hub peft bitsandbytes
# !git clone https://github.com/hssling/criticalcare-copilot.git

# %% [markdown]
# ### Run Benchmark Runner
# By passing the adapter path directly, the benchmark automatically mounts the base Gemma model, applies the dynamic LoRA adapter, and executes the suite against standard datasets.

# %%
import os
os.chdir('/kaggle/working/criticalcare-copilot')
# !python eval/benchmark_runner.py --suite smoke --adapter /kaggle/working/checkpoints/gemma4_e4b_qlora
